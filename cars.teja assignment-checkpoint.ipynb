# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cars=pd.read_csv(r"C:\Users\lenovo\Downloads\mtcars.csv")

# %%
cars
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
cars['mpg'].value_counts()
# Out:
# 21.0    2
# 19.2    2
# 30.4    2
# 22.8    2
# 15.2    2
# 10.4    2
# 21.4    2
# 33.9    1
# 19.7    1
# 15.8    1
# 26.0    1
# 27.3    1
# 13.3    1
# 15.5    1
# 21.5    1
# 24.4    1
# 14.3    1
# 32.4    1
# 14.7    1
# 18.7    1
# 18.1    1
# 17.3    1
# 16.4    1
# 17.8    1
# 15.0    1
# Name: mpg, dtype: int64

# %%
cars['vs'].value_counts()
# Out:
# 0    18
# 1    14
# Name: vs, dtype: int64

# %%
cars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
cars.head(10)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4

# %%
cars.shape   #(row,column)
# Out:
# (32, 11)

# %%
cars.groupby(['wt','gear']).size()
# Out:
# wt     gear
# 1.513  5       1
# 1.615  4       1
# 1.835  4       1
# 1.935  4       1
# 2.140  5       1
# 2.200  4       1
# 2.320  4       1
# 2.465  3       1
# 2.620  4       1
# 2.770  5       1
# 2.780  4       1
# 2.875  4       1
# 3.150  4       1
# 3.170  5       1
# 3.190  4       1
# 3.215  3       1
# 3.435  3       1
# 3.440  3       1
#        4       2
# 3.460  3       1
# 3.520  3       1
# 3.570  3       1
#        5       1
# 3.730  3       1
# 3.780  3       1
# 3.840  3       1
# 3.845  3       1
# 4.070  3       1
# 5.250  3       1
# 5.345  3       1
# 5.424  3       1
# dtype: int64

# %%
cars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df=pd.DataFrame(np.arange(0,20).reshape(5,4),index=['Row1','Row2','Row3','Row4','Row5'],columns=['column1','coulmn2','column3','column4'],dtype=int)
# extra point

# %%
df
# Out:
#       column1  coulmn2  column3  column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
cars
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
sns.countplot(x='mpg',data=cars);

# %%
sns.countplot(x='wt',data=cars);

# %%
sns.countplot(x='vs',data=cars);

# %%
sns.countplot(x='mpg',data=cars,palette='coolwarm');

# %%
sns.boxplot(x=cars['mpg']);

# %%
sns.boxplot(x=cars['mpg'],y=cars['vs']);

# %%
sns.boxplot(x='mpg',y='vs',data=cars);     # another syntax for boxplot

# %%
sns.displot(cars['mpg']);

# %%
sns.displot(cars['mpg'],kde=True);

# %%
sns.jointplot(x='mpg',y='vs',data=cars,kind='scatter');

# %%
sns.jointplot(x='mpg',y='vs',data=cars,kind='reg');

# %%
sns.pairplot(cars);

# %%
sns.countplot(x='mpg',data=cars)
sns.despine();

# %%
sns.countplot(x='mpg',data=cars)
sns.despine(left=True,right=True);   # removes the axis lines

# %%
plt.figure(figsize=(10,10))
sns.set_context('poster',font_scale=2)
sns.countplot(x='mpg',data=cars);

# %%
sns.set_context('paper',font_scale=2)
sns.countplot(x='mpg',data=cars);
